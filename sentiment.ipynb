# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/John Wick NLP Project/john_wick_data.csv')

# %%
df.head()
# Out:
#                        created_at                   id  \
# 0  Sat Apr 08 17:57:22 +0000 2023  1644761366790586375
# 1  Sun Apr 09 08:59:17 +0000 2023  1644988341002342400
# 2  Fri Apr 07 02:39:57 +0000 2023  1644168102840524802
# 3  Tue Apr 04 17:41:16 +0000 2023  1643307762468913156
# 4  Sun Apr 09 10:00:23 +0000 2023  1645003718717501440
#
#                                            full_text lang
# 0  Ryan Gosling, 42, is being criticized on socia...   en
# 1  Frustration lo enni tweet lu Esina \nNuvvu ant...   en
# 2                                John wick 4 was mid   en
# 3  John Wick   //    John Weed https://t.co/trf0s...   en
# 4  I'm the John Wick of giving courtesy likes. ht...   en

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# created_at    object
# id             int64
# full_text     object
# lang          object
# dtype: object

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.dtypes
# Out:
# created_at    datetime64[ns, UTC]
# id                          int64
# full_text                  object
# lang                       object
# dtype: object

# %%
df['full_text']
# Out:
# 0      Ryan Gosling, 42, is being criticized on socia...
# 1      Frustration lo enni tweet lu Esina \nNuvvu ant...
# 2                                    John wick 4 was mid
# 3      John Wick   //    John Weed https://t.co/trf0s...
# 4      I'm the John Wick of giving courtesy likes. ht...
#                              ...
# 96             john wick izleyin https://t.co/PQnsvA1P38
# 97     The stairs of Montmartre, Paris 1937. \n\nBras...
# 98     So Chad Stahelski said during an interview tha...
# 99     I’ve been watching too much John Wick movies x...
# 100    john wick aside, fav keanu reeves film? https:...
# Name: full_text, Length: 101, dtype: object

# %%
#data cleaning
import re

def clean_tweet(tweet):
    # clean #symbol 
    tweet = re.sub(r'#\w+', '', tweet)
    
    # clean @ 
    tweet = re.sub(r'@\w+', '', tweet)
    
    # clean image
    tweet = re.sub(r'http\S+', '', tweet)
    
    # clean space
    tweet = ' '.join(tweet.split())
    
    return tweet

# %%
df['clean_text'] = df['full_text'].apply(clean_tweet)

# %%
df.head()
# Out:
#                  created_at                   id  \
# 0 2023-04-08 17:57:22+00:00  1644761366790586375
# 1 2023-04-09 08:59:17+00:00  1644988341002342400
# 2 2023-04-07 02:39:57+00:00  1644168102840524802
# 3 2023-04-04 17:41:16+00:00  1643307762468913156
# 4 2023-04-09 10:00:23+00:00  1645003718717501440
#
#                                            full_text lang  \
# 0  Ryan Gosling, 42, is being criticized on socia...   en
# 1  Frustration lo enni tweet lu Esina \nNuvvu ant...   en
# 2                                John wick 4 was mid   en
# 3  John Wick   //    John Weed https://t.co/trf0s...   en
# 4  I'm the John Wick of giving courtesy likes. ht...   en
#
#                                           clean_text
# 0  Ryan Gosling, 42, is being criticized on socia...
# 1  Frustration lo enni tweet lu Esina Nuvvu antey...
# 2                                John wick 4 was mid
# 3                             John Wick // John Weed
# ...

# %%
df.tail()
# Out:
#                    created_at                   id  \
# 96  2023-04-06 20:13:00+00:00  1644070724527636480
# 97  2023-04-06 17:07:46+00:00  1644024108840001536
# 98  2023-04-07 06:03:49+00:00  1644219407764422656
# 99  2023-04-06 17:07:13+00:00  1644023967563550720
# 100 2023-04-07 16:00:02+00:00  1644369448176959488
#
#                                              full_text lang  \
# 96           john wick izleyin https://t.co/PQnsvA1P38   en
# 97   The stairs of Montmartre, Paris 1937. \n\nBras...   en
# 98   So Chad Stahelski said during an interview tha...   en
# 99   I’ve been watching too much John Wick movies x...   en
# 100  john wick aside, fav keanu reeves film? https:...   en
#
#                                             clean_text  Sentiment
# 96                                   john wick izleyin          5
# 97       The stairs of Montmartre, Paris 1937. Brassai          5
# 98   So Chad Stahelski said during an interview tha...          2
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 55.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 69.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 22.5 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import numpy

# %%
tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")

# %%
def sentiment_score(review):
    tokens = tokenizer.encode(review, return_tensors='pt')
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
df["Sentiment"] = df["clean_text"].apply(sentiment_score)

# %%
df['Sentiment']
# Out:
# 0      2
# 1      1
# 2      3
# 3      4
# 4      5
#       ..
# 96     5
# 97     5
# 98     2
# 99     2
# 100    1
# Name: Sentiment, Length: 101, dtype: int64

# %%
new_df = pd.concat([df['clean_text'], df['Sentiment']], axis=1)

# %%
new_df
# Out:
#                                             clean_text  Sentiment
# 0    Ryan Gosling, 42, is being criticized on socia...          2
# 1    Frustration lo enni tweet lu Esina Nuvvu antey...          1
# 2                                  John wick 4 was mid          3
# 3                               John Wick // John Weed          4
# 4          I'm the John Wick of giving courtesy likes.          5
# ..                                                 ...        ...
# 96                                   john wick izleyin          5
# 97       The stairs of Montmartre, Paris 1937. Brassai          5
# 98   So Chad Stahelski said during an interview tha...          2
# 99     I’ve been watching too much John Wick movies xD          2
# 100            john wick aside, fav keanu reeves film?          1
#
# [101 rows x 2 columns]

# %%
df['clean_text'][48]
# Out:
# 'John Wick 4 with the best daughter in the world❤️'

# %%
df['Sentiment'][48]
# Out:
# 5
